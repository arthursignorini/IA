# %% [markdown]
# **Vamos experimentar agora o algoritmo Decision Tree?**

# %%
# !pip install -U scikit-learn
# !pip install -U yellowbrick
# Out:
# Requirement already satisfied: scikit-learn in c:\users\phpmm\appdata\local\programs\python\python312\lib\site-packages (1.7.1)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\phpmm\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (2.2.2)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\phpmm\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\phpmm\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\phpmm\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: yellowbrick in c:\users\phpmm\appdata\local\programs\python\python312\lib\site-packages (1.5)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.2 in c:\users\phpmm\appdata\local\programs\python\python312\lib\site-packages (from yellowbrick) (3.10.3)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\phpmm\appdata\local\programs\python\python312\lib\site-packages (from yellowbrick) (1.15.3)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\users\phpmm\appdata\local\programs\python\python312\lib\site-packages (from yellowbrick) (1.7.1)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\phpmm\appdata\local\programs\python\python312\lib\site-packages (from yellowbrick) (2.2.2)
# Requirement already satisfied: cycler>=0.10.0 in c:\users\phpmm\appdata\local\programs\python\python312\lib\site-packages (from yellowbrick) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\phpmm\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\phpmm\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\phpmm\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\phpmm\appdata\roaming\python\python312\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\phpmm\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\phpmm\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\phpmm\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\phpmm\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\phpmm\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=1.0.0->yellowbrick) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\phpmm\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=1.0.0->yellowbrick) (3.6.0)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.tree import DecisionTreeClassifier

# %%
import pickle
with open('../Data/restaurante.pkl', 'rb') as f:
  X_treino, X_teste, y_treino, y_teste = pickle.load(f)

# %%
modelo = DecisionTreeClassifier(criterion='entropy')
Y = modelo.fit(X_treino, y_treino)

# %% [markdown]
# > **Vamos testar o modelo?**

# %%
previsoes = modelo.predict(X_teste)

# %%
previsoes
# Out:
# array(['Nao', 'Sim', 'Sim'], dtype=object)

# %% [markdown]
# > **Será se o modelo acertou?**

# %%
y_teste
# Out:
# 10    Nao
# 9     Nao
# 0     Sim
# Name: Conclusao, dtype: object

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
accuracy_score(y_teste,previsoes)
# Out:
# 0.6666666666666666

# %%
from yellowbrick.classifier import ConfusionMatrix
confusion_matrix(y_teste, previsoes)
# Out:
# array([[1, 1],
#        [0, 1]])

# %%
cm = ConfusionMatrix(modelo)
cm.fit(X_treino, y_treino)
cm.score(X_teste, y_teste)
# Out:
# c:\Users\phpmm\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# 0.6666666666666666

# %%
print(classification_report(y_teste, previsoes))
# Out:
#               precision    recall  f1-score   support
#
#          Nao       1.00      0.50      0.67         2
#          Sim       0.50      1.00      0.67         1
#
#     accuracy                           0.67         3
#    macro avg       0.75      0.75      0.67         3
# weighted avg       0.83      0.67      0.67         3

# %%
from sklearn import tree
previsores = X_treino.columns
figura, eixos = plt.subplots(nrows=1, ncols=1, figsize=(20,40))
tree.plot_tree(modelo, feature_names=previsores, class_names = modelo.classes_, filled=True);
